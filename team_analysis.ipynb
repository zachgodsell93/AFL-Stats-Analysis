# %%
import pandas as pd 
import requests
import json
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import os
from db import query_to_df

# %% [markdown]
# ### Purpose
# In this notebook we look to analyse a teams previous performance in the league and how this may affect their performance in the next season. We will look at the following:
# - What stats are most impactful in determinig a teams performance?
# - How does a teams performance in the previous season affect their performance in the next season?
# - How does a teams performance in the previous season affect their performance in the next season when we take into account the stats that are most impactful?
# - Do teams with certain types of players match up against each other well
# - Can we apply a weighting to a teams players to determine the strength of a team when they come up against another team?

# %%
# Get all the teams from the teams table
teams = query_to_df("SELECT * FROM teams")
# Only keep name and provider_id columns

teams.head()
# Out:
#    id provider_id             name abbreviation nickname
# 0   1      CD_T10   Adelaide Crows         ADEL    Crows
# 1   2      CD_T20   Brisbane Lions           BL    Lions
# 2   3      CD_T40      Collingwood         COLL  Magpies
# 3   4    CD_T1000  Gold Coast Suns         GCFC     Suns
# 4   5      CD_T30          Carlton         CARL    Blues

# %%
# Get seasons from the seasons table
seasons = query_to_df("SELECT * FROM afl_seasons")

seasons.head()
# ID is used for all basic stats
# Provider_id is used for AFL Stats pro
# Out:
#    id  provider_id  year                         name
# 0  53  CD_S2023014  2023  2023 Toyota AFL Premiership
# 1  43  CD_S2022014  2022  2022 Toyota AFL Premiership
# 2  62  CD_S2024014  2024  2024 Toyota AFL Premiership
# 3  34  CD_S2021014  2021  2021 Toyota AFL Premiership
# 4  20  CD_S2020014  2020  2020 Toyota AFL Premiership

# %%
# Get AFL fixture from the fixtures table
# Fixtures table also includes the results of each game if they have been played
fixture_df = query_to_df("SELECT * FROM afl_fixture WHERE comp_season_id = 52")
fixture_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      216 non-null    int64
#  1   round_id                216 non-null    int64
#  2   comp_season_id          216 non-null    int64
#  3   round_number            216 non-null    int64
#  4   venue                   216 non-null    object
#  5   venue_abbreviation      216 non-null    object
#  6   venue_state             216 non-null    object
#  7   utc_start_time          216 non-null    datetime64[ns, UTC]
#  8   status                  216 non-null    object
#  9   home_team_id            216 non-null    int64
#  10  home_team_name          216 non-null    object
#  11  home_team_abbreviation  216 non-null    object
#  12  home_team_nickname      216 non-null    object
#  13  home_team_goals         216 non-null    int64
#  14  home_team_behinds       216 non-null    int64
#  15  home_team_total         216 non-null    int64
#  16  away_team_id            216 non-null    int64
#  17  away_team_name          216 non-null    object
#  18  away_team_abbreviation  216 non-null    object
#  19  away_team_nickname      216 non-null    object
#  20  away_team_goals         216 non-null    int64
#  21  away_team_behinds       216 non-null    int64
#  22  away_team_total         216 non-null    int64
# dtypes: datetime64[ns, UTC](1), int64(12), object(10)
# memory usage: 38.9+ KB

# %%
# Isolate a single team to test with
team = teams[teams['name'] == 'Brisbane Lions']
team_id = team['id'].values[0]

# Filter fixture to only teams games
team_fixture_df = fixture_df[(fixture_df['home_team_id'] == team_id) | (fixture_df['away_team_id'] == team_id)]
# Out:
#        id  round_id  comp_season_id  round_number                  venue  \
# 3    4788       758              52             1          Adelaide Oval
# 10   4794       759              52             2                  Gabba
# 18   4803       760              52             3         Marvel Stadium
# 27   4812       761              52             4                  Gabba
# 39   4823       762              52             5         Adelaide Hills
# 47   4832       763              52             6            Manuka Oval
# 55   4839       764              52             7                  Gabba
# 63   4846       765              52             8         Marvel Stadium
# 77   4863       766              52             9                  Gabba
# 85   4870       767              52            10                  Gabba
# 98   4883       768              52            11          Adelaide Oval
# 108  4893       770              52            13                    MCG
# 115  4902       771              52            14                  Gabba
# 121  4906       772              52            15         Marvel Stadium
# 126  4912       773              52            16                  Gabba
# 137  4922       774              52            17                  Gabba
# 145  4933       775              52            18                    MCG
# 156  4941       776              52            19                  Gabba
# 165  4947       777              52            20  Heritage Bank Stadium
# 179  4963       778              52            21          Optus Stadium
# 183  4968       779              52            22                  Gabba
# 189  4976       780              52            23         Marvel Stadium
# 201  4986       781              52            24                  Gabba
# 210  5842       930              52            25                  Gabba
# 214  5882       945              52            27                  Gabba
# 215  5888       951              52            28                    MCG
#
#     venue_abbreviation venue_state            utc_start_time     status  \
# 3                   AO          SA 2023-03-18 05:35:00+00:00  CONCLUDED
# 10                   G         QLD 2023-03-24 08:55:00+00:00  CONCLUDED
# 18                MRVL         VIC 2023-03-30 08:20:00+00:00  CONCLUDED
# 27                   G         QLD 2023-04-06 09:35:00+00:00  CONCLUDED
# 39                 AHL          SA 2023-04-15 03:10:00+00:00  CONCLUDED
# 47                  MO         ACT 2023-04-22 06:35:00+00:00  CONCLUDED
# 55                   G         QLD 2023-04-29 03:45:00+00:00  CONCLUDED
# 63                MRVL         VIC 2023-05-05 09:50:00+00:00  CONCLUDED
# 77                   G         QLD 2023-05-13 09:25:00+00:00  CONCLUDED
# 85                   G         QLD 2023-05-20 09:30:00+00:00  CONCLUDED
# 98                  AO          SA 2023-05-28 06:40:00+00:00  CONCLUDED
# 108                MCG         VIC 2023-06-10 03:45:00+00:00  CONCLUDED
# 115                  G         QLD 2023-06-16 09:50:00+00:00  CONCLUDED
# 121               MRVL         VIC 2023-06-23 09:50:00+00:00  CONCLUDED
# 126                  G         QLD 2023-06-29 09:20:00+00:00  CONCLUDED
# 137                  G         QLD 2023-07-08 03:45:00+00:00  CONCLUDED
# 145                MCG         VIC 2023-07-14 09:50:00+00:00  CONCLUDED
# 156                  G         QLD 2023-07-22 06:35:00+00:00  CONCLUDED
# 165                HBS         QLD 2023-07-29 06:35:00+00:00  CONCLUDED
# 179                 OS          WA 2023-08-06 06:40:00+00:00  CONCLUDED
# 183                  G         QLD 2023-08-12 06:35:00+00:00  CONCLUDED
# 189               MRVL         VIC 2023-08-18 09:50:00+00:00  CONCLUDED
# 201                  G         QLD 2023-08-26 06:35:00+00:00  CONCLUDED
# 210                  G         QLD 2023-09-09 09:25:00+00:00  CONCLUDED
# 214                  G         QLD 2023-09-23 07:15:00+00:00  CONCLUDED
# 215                MCG         VIC 2023-09-30 04:30:00+00:00  CONCLUDED
#
#      home_team_id  ... home_team_goals home_team_behinds home_team_total  \
# 3               7  ...              18                18               0
# 10              2  ...              14                 9               0
# 18              8  ...              10                 7               0
# 27              2  ...              18                 8               0
# 39              2  ...              22                20               0
# 47             15  ...              13                 9               0
# 55              2  ...              17                13               0
# 63              5  ...              11                 8               0
# 77              2  ...              12                15               0
# 85              2  ...              16                11               0
# 98              1  ...              14                11               0
# 108             9  ...              15                 8               0
# 115             2  ...              13                19               0
# 121            11  ...               8                 8               0
# 126             2  ...              20                14               0
# 137             2  ...              16                20               0
# 145            17  ...              16                 9               0
# 156             2  ...               9                10               0
# 165             4  ...              15                 6               0
# 179            14  ...              11                 8               0
# 183             2  ...              15                 9               0
# 189             3  ...              15                10               0
# 201             2  ...               9                18               0
# 210             2  ...              19                 9               0
# 214             2  ...              11                13               0
# 215             3  ...              12                18               0
#
#      away_team_id     away_team_name  away_team_abbreviation  \
# 3               2     Brisbane Lions                      BL
# 10             17          Melbourne                    MELB
# 18              2     Brisbane Lions                      BL
# 27              3        Collingwood                    COLL
# 39              6    North Melbourne                    NMFC
# 47              2     Brisbane Lions                      BL
# 55             14          Fremantle                     FRE
# 63              2     Brisbane Lions                      BL
# 77             12           Essendon                     ESS
# 85              4    Gold Coast Suns                    GCFC
# 98              2     Brisbane Lions                      BL
# 108             2     Brisbane Lions                      BL
# 115            13       Sydney Swans                     SYD
# 121             2     Brisbane Lions                      BL
# 126            16           Richmond                    RICH
# 137            18  West Coast Eagles                     WCE
# 145             2     Brisbane Lions                      BL
# 156            10       Geelong Cats                    GEEL
# 165             2     Brisbane Lions                      BL
# 179             2     Brisbane Lions                      BL
# 183             1     Adelaide Crows                    ADEL
# 189             2     Brisbane Lions                      BL
# 201            11           St Kilda                     STK
# 210             7      Port Adelaide                    PORT
# 214             5            Carlton                    CARL
# 215             2     Brisbane Lions                      BL
#
#      away_team_nickname away_team_goals away_team_behinds away_team_total
# 3                 Lions              11                 6               0
# 10               Demons              13                 4               0
# 18                Lions               7                11               0
# 27              Magpies              11                17               0
# 39            Kangaroos              12                 5               0
# 47                Lions              16                12               0
# 55              Dockers              10                 7               0
# 63                Lions              15                10               0
# 77              Bombers               6                 9               0
# 85                 Suns               9                10               0
# 98                Lions              10                18               0
# 108               Lions              11                 7               0
# 115               Swans              12                 9               0
# 121               Lions              12                12               0
# 126              Tigers               7                11               0
# 137              Eagles               5                 5               0
# 145               Lions              16                 8               0
# 156                Cats               7                11               0
# 165               Lions               7                13               0
# 179               Lions              11                11               0
# 183               Crows              13                15               0
# 189               Lions              19                10               0
# 201              Saints               9                 6               0
# 210               Power              11                 9               0
# 214               Blues               9                 9               0
# 215               Lions              13                 8               0
#
# [26 rows x 23 columns]
